# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('worldcities.csv')

# %%
df.head()
# Out:
#       city city_ascii      lat       lon      country iso2 iso3   admin_name  \
# 0    Tokyo      Tokyo  35.6897  139.6922        Japan   JP  JPN        Tōkyō
# 1  Jakarta    Jakarta  -6.2146  106.8451    Indonesia   ID  IDN      Jakarta
# 2    Delhi      Delhi  28.6600   77.2300        India   IN  IND        Delhi
# 3   Mumbai     Mumbai  18.9667   72.8333        India   IN  IND  Mahārāshtra
# 4   Manila     Manila  14.6000  120.9833  Philippines   PH  PHL       Manila
#
#    capital  population          id
# 0  primary      37.977  1392685764
# 1  primary      34.540  1360771077
# 2    admin      29.617  1356872604
# 3    admin      23.355  1356226629
# 4  primary      23.088  1608618140

# %%
df.capital.unique()
# Out:
# array(['primary', 'admin', nan, 'minor'], dtype=object)

# %%
df.groupby('country')['population'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
fig, ax = plt.subplots()
pop_sum = df.groupby('country')['population'].sum()
pop_sum.plot.bar(ax=ax)
# Out:
# <AxesSubplot:xlabel='country'>

# %%
df[df.population >= 22]
# Out:
#         city city_ascii      lat       lon      country iso2 iso3  \
# 0      Tokyo      Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1    Jakarta    Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2      Delhi      Delhi  28.6600   77.2300        India   IN  IND
# 3     Mumbai     Mumbai  18.9667   72.8333        India   IN  IND
# 4     Manila     Manila  14.6000  120.9833  Philippines   PH  PHL
# 5   Shanghai   Shanghai  31.1667  121.4667        China   CN  CHN
# 6  São Paulo  Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
#
#     admin_name  capital  population          id
# 0        Tōkyō  primary      37.977  1392685764
# 1      Jakarta  primary      34.540  1360771077
# 2        Delhi    admin      29.617  1356872604
# 3  Mahārāshtra    admin      23.355  1356226629
# 4       Manila  primary      23.088  1608618140
# 5     Shanghai    admin      22.120  1156073548
# 6    São Paulo    admin      22.046  1076532519
